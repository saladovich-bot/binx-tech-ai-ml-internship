# %% [markdown]
# Load and clean a provided dataset with Pandas (handling any missing values):

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data.csv")

df.head(10)
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories
# 0        60  '2020/12/01'    110       130     409.1
# 1        60  '2020/12/02'    117       145     479.0
# 2        60  '2020/12/03'    103       135     340.0
# 3        45  '2020/12/04'    109       175     282.4
# 4        45  '2020/12/05'    117       148     406.0
# 5        60  '2020/12/06'    102       127     300.0
# 6        60  '2020/12/07'    110       136     374.0
# 7       450  '2020/12/08'    104       134     253.3
# 8        30  '2020/12/09'    109       133     195.1
# 9        60  '2020/12/10'     98       124     269.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  32 non-null     int64
#  1   Date      31 non-null     object
#  2   Pulse     32 non-null     int64
#  3   Maxpulse  32 non-null     int64
#  4   Calories  30 non-null     float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 1.4+ KB

# %%
df.isnull().sum()
# Out:
# Duration    0
# Date        1
# Pulse       0
# Maxpulse    0
# Calories    2
# dtype: int64

# %%
df["Date"] = df["Date"].fillna(df["Date"].mode()[0])
df["Calories"] = df["Calories"].fillna(df["Calories"].mean())
df.isnull().sum()
# Out:
# Duration    0
# Date        0
# Pulse       0
# Maxpulse    0
# Calories    0
# dtype: int64

# %%
print(df.duplicated().sum())
# Out:
# 1

# %%
df.drop_duplicates(inplace=True)

# %%
print(df.duplicated().sum())
# Out:
# 0

# %% [markdown]
# Use NumPy to compute at least one derived numeric feature or summary statistic:

# %%
mean_duration = np.mean(df["Duration"])
print("Duration avg =", mean_duration)
# Out:
# Duration avg = 68.70967741935483

# %% [markdown]
# Produce at least three labeled plots (including a histogram and a scatter plot) exploring the data:
# And
# Write Markdown cells explaining what each visualization reveals about the data:

# %%
plt.scatter(df["Pulse"], df["Calories"])
plt.title("Pulse VS Calories")
plt.xlabel("Pulse")
plt.ylabel("Calories")
plt.show()

# %% [markdown]
# the scatter plot explains a positive relationship between Pulse and Calories, But the relationship is not perfectly linear.
# this mwans that when the pulse increase, the Calories increases too. there ia an outliers.

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))
axes[0].hist(df["Maxpulse"])
axes[0].set_title("Maxpulse distribution")
axes[1].scatter(df["Maxpulse"], df["Calories"])
axes[1].set_title("Maxpulse vs. Calories")
plt.tight_layout()
plt.show()

# %% [markdown]
# The Maxpulse distribution high between 115-137, and there is an outliers when the Maxpulse up 170.
# there is a positive relationship between Maxpulse and Calories, not perfectly linear. there is an outliers, for example when the maxpulse is 170 and calories is 280. in general when maxpulse increase, calories increase too.
