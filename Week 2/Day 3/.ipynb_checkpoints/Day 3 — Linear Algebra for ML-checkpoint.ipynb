# %%
import numpy as np

# %% [markdown]
# Represent three data samples as a (3 × features) NumPy matrix:

# %%
products = np.array([[40, 5000, 2],
                     [63, 2500, 4],
                     [22, 500, 10]])
print(products.shape)
# Out:
# (3, 3)

# %% [markdown]
# Compute the dot product of one sample vector with a weight vector by hand, then verify it with
# np.dot:

# %%
weights = np.array([0.1, 0.0002, 1.5])

by_hand = 40*0.1 + 5000*0.0002 + 2*1.5
print(by_hand)
prediction = np.dot(products[0], weights)
print(prediction)
# Out:
# 8.0
# 8.0

# %% [markdown]
# Use matrix multiplication (@) to produce a prediction for all three samples at once:

# %%
prediction = products @ weights
print(prediction)
# Out:
# [ 8.  12.8 17.3]

# %% [markdown]
#  Deliberately create a shape-mismatch error, read the message, and explain in Markdown why it
# occurred and how to fix it:

# %%
wrong_weights = np.array([0.2, 0.005])
prediction = wrong_weights * products
print(prediction)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 2
#       1 wrong_weights = np.array([0.2, 0.005])
# ----> 2 prediction = wrong_weights * products
#       3 print(prediction)
#
# ValueError: operands could not be broadcast together with shapes (2,) (3,3)

# %% [markdown]
# the of two matrices isn't match each others, in linear algebra we can't multiply (2,) (3,3), we can fix it by matching the shape of weights
